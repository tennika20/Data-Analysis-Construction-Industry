# %%
import pandas as pd
import plotly.express as px

# %%
data = pd.read_csv("all_metro_employment.csv")

# %%
# convert the Purchase Date to datetime
data['time'] = pd.to_datetime(data['time'])
# add a column for Year
data['Year'] = data['time'].dt.year
data = data[data['Year']!=2021]
data = data.rename(columns={'Mining, Logging and Construction': 'Employment Rate'})

# %%
data
# Out:
#          state                          area       time  Total Nonfarm  \
# 0      Alabama  Anniston-Oxford-Jacksonville 2011-01-01           48.3
# 1      Alabama  Anniston-Oxford-Jacksonville 2011-02-01           48.2
# 2      Alabama  Anniston-Oxford-Jacksonville 2011-03-01           48.6
# 3      Alabama  Anniston-Oxford-Jacksonville 2011-04-01           48.6
# 4      Alabama  Anniston-Oxford-Jacksonville 2011-05-01           48.6
# ...        ...                           ...        ...            ...
# 57775  Wyoming                      Cheyenne 2020-08-01           46.7
# 57776  Wyoming                      Cheyenne 2020-09-01           46.5
# 57777  Wyoming                      Cheyenne 2020-10-01           46.7
# 57778  Wyoming                      Cheyenne 2020-11-01           46.0
# 57779  Wyoming                      Cheyenne 2020-12-01           46.0
#
#        Employment Rate  Manufacturing  Trade, Transportation, and Utilities  \
# 0                  1.0            5.7                                   9.0
# 1                  0.9            5.7                                   8.9
# 2                  1.0            5.7                                   9.0
# 3                  0.9            5.7                                   9.0
# 4                  1.0            5.6                                   9.1
# ...                ...            ...                                   ...
# 57775              3.8            1.3                                   9.9
# 57776              3.7            1.2                                   9.9
# 57777              3.9            1.2                                   9.9
# 57778              3.6            1.2                                  10.0
# 57779              3.5            1.2                                  10.0
#
#        Information  Financial Activities  Professional and Business Services  \
# 0              0.7                   1.3                                 5.6
# 1              0.7                   1.3                                 5.7
# 2              0.7                   1.3                                 5.6
# 3              0.7                   1.3                                 5.6
# 4              0.7                   1.3                                 5.6
# ...            ...                   ...                                 ...
# 57775          0.8                   2.3                                 4.0
# 57776          0.8                   2.3                                 4.0
# 57777          0.8                   2.3                                 4.0
# 57778          0.8                   2.2                                 3.9
# 57779          0.8                   2.3                                 3.9
#
#        Education and Health Services  Leisure and Hospitality  Government  \
# 0                                5.3                      4.5        13.5
# 1                                5.3                      4.5        13.5
# 2                                5.3                      4.7        13.6
# 3                                5.3                      4.8        13.6
# 4                                5.3                      4.7        13.6
# ...                              ...                      ...         ...
# 57775                            4.6                      4.8        13.7
# 57776                            4.6                      4.7        13.8
# 57777                            4.7                      4.6        13.8
# 57778                            4.7                      4.4        13.7
# 57779                            4.7                      4.4        13.7
#
#        Year
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2011
# ...     ...
# 57775  2020
# 57776  2020
# 57777  2020
# 57778  2020
# 57779  2020
#
# [55920 rows x 14 columns]

# %%
now = data.groupby(by =['state','Year'])['Employment Rate'].sum().to_frame(name = 'Employment Rate').reset_index()
#now['Year'] = pd.to_datetime(now.Year)
now = now.sort_values(by=['state','Year'])
now = now.reset_index(drop = True)
now
# Out:
#        state  Year  Employment Rate
# 0    Alabama  2011            889.7
# 1    Alabama  2012            880.3
# 2    Alabama  2013            870.6
# 3    Alabama  2014            863.8
# 4    Alabama  2015            876.6
# ..       ...   ...              ...
# 505  Wyoming  2016            106.0
# 506  Wyoming  2017            102.8
# 507  Wyoming  2018            110.3
# 508  Wyoming  2019            118.0
# 509  Wyoming  2020            100.2
#
# [510 rows x 3 columns]

# %%
fig = px.line(data_frame =now , x= 'Year', y= "Employment Rate" ,facet_col="state", facet_col_wrap=10)
              #title= "Overall Employment trend in construction across all states from 2011 - 2020")

#fig = px.line(data_frame =now , x= 'Year', y= "Mining, Logging and Construction" ,facet_col="state", facet_col_wrap=10,
 #             title= "Employment trend in construction sector during COVID across states")

fig.update_layout(
    autosize=True, 
    width=1800,
    height=1400,
    margin=dict(
        
        l=50,
        r=50,
        b=100,
        t=100,
        pad=4
    ),
)
fig.update_layout(title=f"Figure : Overall Employment trend in construction across all states from 2011 - 2020 ", title_y = 0.01, title_x = 0.5)
#fig.update_yaxes(range = [0,1500])
fig.update_xaxes(title_text ='Year')
fig.update_yaxes(matches = None, showticklabels = True, visible = True)
# Out:
# <div>                            <div id="c5878b50-34eb-4f4c-b1a5-a8b549a4933f" class="plotly-graph-div" style="height:1400px; width:1800px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c5878b50-34eb-4f4c-b1a5-a8b549a4933f")) {                    Plotly.newPlot(                        "c5878b50-34eb-4f4c-b1a5-a8b549a4933f",                        [{"hovertemplate":"state=Alabama<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x51","y":[889.7,880.3,870.6,863.8,876.6,883.4,902.1,945.4,990.0,979.2],"yaxis":"y51","type":"scatter"},{"hovertemplate":"state=Alaska<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x52","y":[198.4,211.2,212.0,218.4,220.3,196.6,185.6,191.4,198.0,189.4],"yaxis":"y52","type":"scatter"},{"hovertemplate":"state=Arizona<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x53","y":[1346.0,1413.8,1497.7,1514.0,1552.7,1628.2,1754.5,1914.0,2064.1,2090.2],"yaxis":"y53","type":"scatter"},{"hovertemplate":"state=Arkansas<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x54","y":[840.0,843.7,831.7,836.6,859.5,864.1999999999999,880.1,887.5,918.4,913.2],"yaxis":"y54","type":"scatter"},{"hovertemplate":"state=California<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x55","y":[9766.4,10276.0,11059.9,11638.3,12555.2,13346.3,13903.4,14724.2,15078.2,14519.3],"yaxis":"y55","type":"scatter"},{"hovertemplate":"state=Colorado<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x56","y":[1362.5,1431.3,1560.4,1770.2,1823.6,1837.9,1959.0,2092.3,2161.5,2049.0],"yaxis":"y56","type":"scatter"},{"hovertemplate":"state=Connecticut<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x57","y":[764.9,767.5,794.9,824.6,850.6,869.0,852.1,856.9,865.9,813.3],"yaxis":"y57","type":"scatter"},{"hovertemplate":"state=Delaware<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[2011,2012,2013,2014,2015,2016,2017,2018,2019,2020],"xaxis":"x58","y":[668.2,650.8,674.0,675.9,709.0,736.0,747.5,753.3,772.3,741.9],"yaxis":"y58","type":"scatter"},{"hovertemplate":"state=District of Columbia<br>Year=%{x}<br>Employment Rate=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circl ...

# %%
import csv
from collections import defaultdict
import plotly.express as px
import cv2
from matplotlib import pyplot as plt

def main():
    def anon():
        return defaultdict(float)
    state_yr_to_y = defaultdict(anon)
    with open('all_metro_employment.csv') as data:
        reader = csv.DictReader(data)
        for row in reader:
            year = row['time'][-4:]
            if year == '2021':
                continue
            state = row['state']
            state_yr_to_y[state][year] += float(row['Mining, Logging and Construction'])
    ctr = 1
    # _, axs = plt.subplots(8, 7, figsize=(12, 12))
    # axs = axs.flatten()
    plot_dict = {'States': list(state_yr_to_y.keys())}
    plot_dict['Employment rate'] = [sum(state_yr_to_y[key].values()) for key in plot_dict['States']]

        # fig1.add_subplot(7, 8, ctr)
        # img = cv2.imread(f"out/{state}.png")
        # plt.imshow(img)
        # plt.axis('off')
    mx,mn = max(plot_dict['Employment rate']),min(plot_dict['Employment rate'])
    res = []
    for i in plot_dict['Employment rate']:
        if i in (mn,mx):
            res.append(int(i))
        else:
            res.append("")
    fig = px.line(plot_dict, x='States', y='Employment rate', text=res, width=1000)
    fig.update_layout(title=f"Overall trend in construction sector in all states", title_y=0.01)
#     fig.write_image(f"allmix1.png")
    print(fig.show())

main()
# Out:
# <div>                            <div id="72cb655c-c53a-4290-ace3-9a0a51873fdc" class="plotly-graph-div" style="height:525px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72cb655c-c53a-4290-ace3-9a0a51873fdc")) {                    Plotly.newPlot(                        "72cb655c-c53a-4290-ace3-9a0a51873fdc",                        [{"hovertemplate":"States=%{x}<br>Employment rate=%{y}<br>text=%{text}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"markers+lines+text","name":"","orientation":"v","showlegend":false,"text":["","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","","",165543,"","","","","","","",686,"",""],"x":["Alabama","Alaska","Arizona","Arkansas","Tennessee","Texas","California","Colorado","Connecticut","Massachusetts","District of Columbia","Delaware","Pennsylvania","Florida","Georgia","Hawaii","Idaho","Utah","Illinois","Missouri","Indiana","Ohio","Kentucky","Iowa","Nebraska","Kansas","West Virginia","Louisiana","Maine","New Hampshire","Maryland","Rhode Island","Michigan","Minnesota","North Dakota","Wisconsin","Mississippi","Montana","Nevada","New Jersey","New York","New Mexico","North Carolina","Virginia","Oklahoma","Oregon","South Carolina","South Dakota","Vermont","Washington","Wyoming"],"xaxis":"x","y":[9081.100000000002,2021.3000000000002,16775.2,8674.899999999998,20639.7,121189.39999999997,126867.20000000001,18047.7,8259.700000000003,44561.19999999998,131521.6,7128.899999999999,78182.4,59334.79999999997,34267.70000000001,3053.1000000000004,3761.0999999999995,10545.699999999999,81251.79999999999,36347.6,15045.199999999992,33272.49999999999,8931.300000000001,16727.799999999996,7182.1,5072.1,6022.200000000003,20885.3,1800.2,2727.7,16033.8,5355.800000000001,22595.6,22334.600000000006,3350.2,10450.300000000003,2956.4000000000005,4842.3,8375.7,15414.9,165543.80000000005,4714.1,28599.6,23058.9,9462.999999999998,18335.600000000002,11066.900000000001,1542.6,686.8999999999999,31834.300000000003,1163.9],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"t ...
# None

# %%
import csv
from collections import defaultdict
import plotly.express as px
import os
 


def main():
    def anon():
        return defaultdict(float)
    state_yr_to_y = defaultdict(anon)
    with open('all_metro_employment.csv') as data:
        reader = csv.DictReader(data)
        for row in reader:
            year = row['time'][-4:]
            if year == '2021':
                continue
            state = row['state']
            state_yr_to_y[state][year] += float(row['Mining, Logging and Construction'])
    for state in state_yr_to_y:
        plot_dict = {'Years': list(state_yr_to_y[state].keys())}
        plot_dict['Employment rate'] = [state_yr_to_y[state][key] for key in plot_dict['Years']]
        fig = px.line(plot_dict, x='Years', y='Employment rate',
                      title=f"Overall trend in construction sector in {state}")
        
 
            
        fig.write_image("./images/"+f"{state}.png")
            
      
        
        #pio.write_image(fig,f"out/{state}.png", width=1980, height=1980)

        
        
# Specify path
path = './images'
 
isExist = os.path.exists(path)
 
if(isExist==False):
    os.mkdir("./images")
    
main()

# %%
import cv2
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(56, 49))
rows = 3
columns = 2
# reading images
Image1 = cv2.imread("./images/Arizona.png")
Image2 = cv2.imread('./images/Idaho.png')
Image3 = cv2.imread('./images/Utah.png')
Image4 = cv2.imread('./images/South Dakota.png')
Image5 = cv2.imread('./images/Nebraska.png')
fig.add_subplot(rows, columns, 1)
plt.imshow(Image1, aspect=0.8)
plt.axis('off')
plt.title("Arizona",fontsize= 45)
fig.add_subplot(rows, columns, 2)
plt.imshow(Image2, aspect=0.8)
plt.axis('off')
plt.title("Idaho",fontsize= 45)

fig.add_subplot(rows, columns, 3)
plt.imshow(Image3,aspect=0.8)
plt.axis('off')
plt.title("Utah",fontsize= 45)

fig.add_subplot(rows, columns, 4)
plt.imshow(Image4,aspect=0.8)
plt.axis('off')
plt.title("South Dakota",fontsize= 45)

fig.add_subplot(rows, columns, 5)
plt.imshow(Image5,aspect=0.8)
plt.axis('off')
plt.title("Nebraska",fontsize= 45)

# plt.savefig("uneven.jpg")
plt.show()

# %%
import cv2
from matplotlib import pyplot as plt
fig = plt.figure(figsize=(56, 49))
# reading images
Image1 = cv2.imread("./images/West Virginia.png")
fig.add_subplot(111)
plt.imshow(Image1, aspect=0.8)
plt.axis('off')

plt.annotate(
    # Label and coordinate
    'From 2017-2018, there \nis an increase due to \npipeline project', xy=(461.5, 340.1), xytext=(394, 254),
    # Custom arrow
    size=11, arrowprops=dict(facecolor='black', shrink=0.05))
plt.savefig("./images/west.png")
plt.show()
